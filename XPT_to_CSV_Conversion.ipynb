# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# The -d flag tells it where to put the files (the /content folder)
# !unzip /content/drive/MyDrive/Diabetes_Prediction_Model.zip -d /content/dataset/
# Out:
# Archive:  /content/drive/MyDrive/Diabetes_Prediction_Model.zip
#    creating: /content/dataset/Diabete Prection Model/
#   inflating: /content/dataset/Diabete Prection Model/LLCP2020.XPT
#   inflating: /content/dataset/Diabete Prection Model/LLCP2021.XPT
#   inflating: /content/dataset/Diabete Prection Model/LLCP2022.XPT
#   inflating: /content/dataset/Diabete Prection Model/LLCP2023.XPT
#   inflating: /content/dataset/Diabete Prection Model/LLCP2024.XPT

# %%
# !pip install pandas-gbq pyarrow --quiet

# %%
reader_2020= pd.read_sas('/content/dataset/Diabete Prection Model/LLCP2020.XPT')
reader_2020_CSV = reader_2020.to_csv('/content/dataset/Diabete Prection Model/LLCP2020.csv',index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp "/content/dataset/Diabete Prection Model/LLCP2020.csv" "/content/drive/MyDrive/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
reader_2021= pd.read_sas('/content/dataset/Diabete Prection Model/LLCP2021.XPT')
reader_2021_CSV = reader_2021.to_csv('/content/dataset/Diabete Prection Model/LLCP2021.csv',index=False)

# %%
reader_2022= pd.read_sas('/content/dataset/Diabete Prection Model/LLCP2022.XPT')
reader_2022_CSV = reader_2022.to_csv('/content/dataset/Diabete Prection Model/LLCP2022.csv',index=False)

# %%
# !cp "/content/dataset/Diabete Prection Model/LLCP2022.csv" "/content/drive/MyDrive/"
# !cp "/content/dataset/Diabete Prection Model/LLCP2021.csv" "/content/drive/MyDrive/"

# %%
reader_2023= pd.read_sas('/content/dataset/Diabete Prection Model/LLCP2023.XPT')
reader_2023_CSV = reader_2023.to_csv('/content/dataset/Diabete Prection Model/LLCP2023.csv',index=False)

# %%
reader_2024= pd.read_sas('/content/dataset/Diabete Prection Model/LLCP2024.XPT')
reader_2024_CSV = reader_2024.to_csv('/content/dataset/Diabete Prection Model/LLCP2024.csv',index=False)

# %%
# !cp "/content/dataset/Diabete Prection Model/LLCP2023.csv" "/content/drive/MyDrive/"
# !cp "/content/dataset/Diabete Prection Model/LLCP2024.csv" "/content/drive/MyDrive/"
